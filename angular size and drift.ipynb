# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import axes3d

# %%
img1 = cv2.imread("Test/canon 15 march/TIF converts/IMG_0312.tif",0|cv2.IMREAD_IGNORE_ORIENTATION)
img2 = cv2.imread("Test/canon 15 march/TIF converts/IMG_0313.tif",0|cv2.IMREAD_IGNORE_ORIENTATION)

# %%
plt.imshow(img1[2420:2520,330:430]/2**8)
maxindex1 = np.argmax(img1)
print(maxindex1/4000)
print(maxindex1%4000)
# Out:
# 2443.09475
# 379

# %%
plt.imshow(img2[2565:2665,1391:1491]/2**8)
maxindex2 = np.argmax(img2)
print(maxindex2/4000)
print(maxindex2%4000)
# Out:
# 2595.35775
# 1431

# %%
dist = np.sqrt((2615-2470)**2 + (1441 - 380)**2)
print(dist)
# Out:
# 1070.862269388552

# %%
#time between images
